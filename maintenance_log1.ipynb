# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mn=pd.read_csv(r'/Users/swagat/Downloads/maintenance_data.csv')
mn

# %%
mn.isnull().sum()

# %%
mn.describe()

# %%
mn.dtypes

# %%
for i in mn.columns:
    print(i,':','\n',mn[i].unique(),'\n')

# %%
sns.boxplot(x=mn.lifetime,palette='bright')
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='broken', data=mn)
plt.title("Machine Failure Distribution")
plt.xlabel("Broken (0=No, 1=Yes)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(mn['lifetime'], bins=15, kde=True)
plt.title("Distribution of Lifetime")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(mn['pressureInd'], bins=15, kde=True)
plt.title("Pressure Indicator Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(mn['moistureInd'], bins=15, kde=True)
plt.title("Moisture Indicator Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(mn['temperatureInd'], bins=15, kde=True)
plt.title("Temperature Indicator Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='broken', y='temperatureInd', data=mn)
plt.title("Temperature vs Machine Failure")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(x='pressureInd', y='temperatureInd', hue='broken', data=mn)
plt.title("Pressure vs Temperature")
plt.show()

# %%
sns.pairplot(mn, hue='broken')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(mn.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
mn['team'] = le.fit_transform(mn['team'])
mn.team.unique()

# %%
le.inverse_transform([0,2,1])

# %%
mn.team.unique()

# %%
mn['provider'] = le.fit_transform(mn['provider'])
mn.provider.unique()

# %%
le.inverse_transform([3, 0, 1, 2])

# %%
print(mn.head(5))

# %%
ip=mn.drop('broken',axis=1)
op=mn.broken

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2,random_state=42)

# %%
print(x_train.shape)

# %%
from sklearn.preprocessing import MinMaxScaler
mm= MinMaxScaler()
x_train=mm.fit_transform(x_train)
x_test=mm.transform(x_test)

# %%
x_train

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression(random_state=0)

# %%
model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %%
y_pred

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# %%
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=model.classes_
)

disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
df=pd.DataFrame({'y_test':list(y_test),'Prediction':y_pred})
df

# %%
sns.lmplot(x='y_test', y='Prediction', data=df, logistic=True, line_kws={'color':'red'})
plt.show()
